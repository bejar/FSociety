# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Stock Analysis

# %%
from FSociety.Data import ActivityStatistics, HFTStatistics, Company, Stock,MPI
from FSociety.Config import stat

# %%
st = Stock(num=50)
comp = Company()
print(sorted(st.get_list_stocks()))
# Out:
# ['AAPL', 'ABX', 'AMD', 'AMZN', 'ATVI', 'BAC', 'BBL', 'C', 'CSCO', 'DIA', 'EWZ', 'FAS', 'FB', 'GDX', 'GDXJ', 'GILD', 'GLD', 'GOOG', 'GOOGL', 'INTC', 'IVV', 'IWM', 'JNUG', 'JPM', 'KRE', 'MS', 'MSFT', 'MU', 'NEM', 'NUGT', 'NVDA', 'QLD', 'QQQ', 'RIO', 'SPY', 'SSO', 'TLT', 'TNA', 'UCO', 'UVXY', 'VOO', 'VXX', 'WFC', 'X', 'XIV', 'XLE', 'XLV', 'XLY', 'XOP', 'YHOO']

# %%
year = '2017G'
day= 0
stock = 'GOOGL'
print(comp.get_company(stock))
# Out:
# ['Alphabet Inc.', 'Technology', 'Computer Software: Programming', 'Data Processing']

# %% [markdown]
# ## Day activity

# %%
activity = ActivityStatistics(year,day=day,stock=stock)

# %%
activity.log()
# Out:
# N Buy orders: 182692
# N Sell orders: 140001
# N Order Executions Sell: 4034
# Mean time to execution: 00:01:43.350.733.604
# Max time to execution: 05:51:28.244.368.254
# Min time to execution: 00:00:00.000.003.340
# N Order Executions Buy: 6296
# Mean time to execution: 00:03:31.331.451.324
# Max time to execution: 03:46:28.417.770.080
# Min time to execution: 00:00:00.000.000.238

# %%
activity.plot_statistics_deltatimes(type='sell',kde=True, bins=20)

# %%
activity.plot_statistics_deltatimes(type='buy',kde=True, bins=20)

# %%
activity.plot_statistics_deltatimes(type='delete',kde=True, bins=20)

# %%
activity.plot_statistics_deltatimes(type='all',kde=True, bins=20)

# %%
activity.plot_statistics_prices(type='order')

# %%
activity.plot_statistics_prices(type='execution')

# %%
activity.plot_statistics_sizes(type='order',bins=20)

# %%
activity.plot_statistics_sizes(type='execution',bins=20)

# %%
activity.plot_price_evolution()

# %% [markdown]
# ## Month Activity

# %%
activity = ActivityStatistics(year='2017G',stock=stock,heat=True)
activity2 = ActivityStatistics(year='2016G',stock=stock,heat=True)
activity3 = ActivityStatistics(year='2018G',stock=stock,heat=True)

# %%
activity2.plot_deltatime_heatmap(side='buy', type='execution')
activity.plot_deltatime_heatmap(side='buy', type='execution')
activity3.plot_deltatime_heatmap(side='buy', type='execution')

# %%
activity2.plot_deltatime_heatmap(side='sell', type='execution')
activity.plot_deltatime_heatmap(side='sell', type='execution')
activity3.plot_deltatime_heatmap(side='sell', type='execution')

# %%
activity2.plot_deltatime_heatmap(side='buy', type='delete')
activity.plot_deltatime_heatmap(side='buy', type='delete')
activity3.plot_deltatime_heatmap(side='buy', type='delete')

# %%
activity2.plot_deltatime_heatmap(side='sell', type='delete')
activity.plot_deltatime_heatmap(side='sell', type='delete')
activity3.plot_deltatime_heatmap(side='sell', type='delete')

# %%
activity = ActivityStatistics(year='2017G',stock=stock)
activity2 = ActivityStatistics(year='2016G',stock=stock)
activity3 = ActivityStatistics(year='2018G',stock=stock)

# %%
activity2.plot_deltatime_violinplot(side='buy', type='execution')
activity.plot_deltatime_violinplot(side='buy', type='execution')
activity3.plot_deltatime_violinplot(side='buy', type='execution')

# %%
activity2.plot_deltatime_violinplot(side='sell', type='execution')
activity.plot_deltatime_violinplot(side='sell', type='execution')
activity3.plot_deltatime_violinplot(side='sell', type='execution')

# %%
activity2.plot_deltatime_violinplot(side='buy', type='delete')
activity.plot_deltatime_violinplot(side='buy', type='delete')
activity3.plot_deltatime_violinplot(side='buy', type='delete')

# %%
activity2.plot_deltatime_violinplot(side='sell', type='delete')
activity.plot_deltatime_violinplot(side='sell', type='delete')
activity3.plot_deltatime_violinplot(side='sell', type='delete')

# %% [markdown]
# ## Time Frame activity

# %%
timeactivity = HFTStatistics(year,day,stock, merge=True, hft=False)
# Out:
# DAY: 020117 STOCK GOOGL

# %%
print(stat)
# Out:
# ['price', 'gap', 'lenbuy', 'lensell', 'lenbuy5', 'lensell5', 'lenbuy10', 'lensell10', 'otherprice', 'size']

# %%
timeactivity.single_distplot(side='buy', statistic='price',bins=20,kde=True)

# %%
timeactivity.single_otherplot(side='buy', statistic='price',plot='box')

# %%
timeactivity.single_distplot(side='sell', statistic='price',bins=20,kde=True)
timeactivity.single_otherplot(side='sell', statistic='price',plot='box')

# %%
timeactivity.single_distplot(side='buy', statistic='gap',bins=20,kde=True)
timeactivity.single_otherplot(side='buy', statistic='gap',plot='boxen')

# %%
timeactivity.single_distplot(side='sell', statistic='gap',bins=20,kde=True)
timeactivity.single_otherplot(side='sell', statistic='gap',plot='boxen')

# %%
timeactivity.single_distplot(side='buy', statistic='lensell10',bins=20,kde=True)
timeactivity.single_otherplot(side='buy', statistic='lensell10',plot='boxen')

# %%
timeactivity.single_distplot(side='buy', statistic='lenbuy10',bins=20,kde=True)
timeactivity.single_otherplot(side='buy', statistic='lenbuy10',plot='boxen')

# %%
timeactivity.single_distplot(side='sell', statistic='lenbuy10',bins=20,kde=True)
timeactivity.single_otherplot(side='sell', statistic='lenbuy10',plot='boxen')

# %%
timeactivity.single_distplot(side='sell', statistic='lensell10',bins=20,kde=True)
timeactivity.single_otherplot(side='sell', statistic='lensell10',plot='boxen')

# %%
timeactivity.single_distplot(side='buy', statistic='otherprice',bins=20,kde=True)
timeactivity.single_otherplot(side='buy', statistic='otherprice',plot='boxen')

# %%
timeactivity.single_distplot(side='sell', statistic='otherprice',bins=20,kde=True)
timeactivity.single_otherplot(side='sell', statistic='otherprice',plot='boxen')

# %%
timeactivity.single_distplot(side='buy', statistic='size',bins=20,kde=True)
timeactivity.single_otherplot(side='buy', statistic='size',plot='boxen')

# %%
timeactivity.single_distplot(side='sell', statistic='size',bins=20,kde=True)
timeactivity.single_otherplot(side='sell', statistic='size',plot='boxen')

# %%
lvars = ['gap','otherprice','lenbuy5','lensell5','size']

# %%
timeactivity.pair_plot(lvars,side='buy',bins=20,kde=False)

# %%
timeactivity.pair_plot(lvars,side='sell',bins=20,kde=False)
