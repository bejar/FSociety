# %% [markdown]
# # ITCH NASDAQ Order execution analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from FSociety.Data.TimeLineSummary import timelines, ntimelines, stat, order_exec_analysis

# %%
print(stat)
print(timelines)
print(ntimelines)
# Out:
# ['price', 'gap', 'lenbuy', 'lensell', 'lenbuy5', 'lensell5', 'lenbuy10', 'lensell10', 'otherprice']
# [10000000000, 1000000000, 100000000, 10000000, 1000000, 100000, 10000, 0]
# ['inf-10s', '10s-1s', '1s-100ms', '100ms-10ms', '10ms-1ms', '1ms-100 mcs', '100mcs-10mcs', '10mcs-0']

# %%
def plot_dist(s, v):
    plt.figure(figsize=(20,10))
    plt.title(f'{stock} {s} {v}')
    for i in timelines[1:-1]:
        sns.distplot(statistics[i][s][v], label=ntimelines[timelines.index(i)], norm_hist=True, bins=50)
    plt.legend()

# %%
stock= 'GOOGL'
year = '2017G'
day = 0

# %%
statistics = order_exec_analysis(year, day, stock)
# Out:
# Opening: 020117-GOOGL

# %% [markdown]
# ## Estadisticas - COMPRAS

# %% [markdown]
# Distribucion entre la diferencia entre el precio de ejecucion y el siguiente precio para la ejecuciones de compras

# %%
plot_dist('buy', 'gap')

# %% [markdown]
# Distribucion de los precios de compra de las ejecuciones

# %%
plot_dist('buy', 'price')

# %% [markdown]
# Distribucion de la difencia entre el precio de compra y el mejor precio de venta en el momento de la ejecucion

# %%
plot_dist('buy', 'otherprice')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes en el momento de la ejecucion

# %%
plot_dist('buy', 'lenbuy')

# %% [markdown]
# Distribucion del numero de ordenes de ventas pendientes en el momento de la ejecucion

# %%
plot_dist('buy', 'lensell')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 5 mejores precios en el momento de la ejecucion

# %%
plot_dist('buy', 'lenbuy5')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 10 mejores precios en el momento de la ejecucion

# %%
plot_dist('buy', 'lenbuy10')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 5 mejores precios en el momento de la ejecucion

# %%
plot_dist('buy', 'lensell5')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 5 mejores precios en el momento de la ejecucion

# %%
plot_dist('buy', 'lensell10')

# %% [markdown]
# ## Estadisticas - VENTAS

# %% [markdown]
# Distribucion entre la diferencia entre el precio de ejecucion y el siguiente precio para la ejecuciones de ventas

# %%
plot_dist('sell', 'gap')

# %% [markdown]
# Distribucion de los precios de venta de las ejecuciones

# %%
plot_dist('sell', 'price')

# %% [markdown]
# Distribucion de la difencia entre el precio de venta y el mejor precio de compra en el momento de la ejecucion

# %%
plot_dist('sell', 'otherprice')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes en el momento de la ejecucion

# %%
plot_dist('sell', 'lenbuy')

# %% [markdown]
# Distribucion del numero de ordenes de ventas pendientes en el momento de la ejecucion

# %%
plot_dist('sell', 'lensell')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 5 mejores precios en el momento de la ejecucion

# %%
plot_dist('sell', 'lenbuy5')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 10 mejores precios en el momento de la ejecucion

# %%
plot_dist('sell', 'lenbuy10')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 5 mejores precios en el momento de la ejecucion

# %%
plot_dist('sell', 'lensell5')

# %% [markdown]
# Distribucion del numero de ordenes de compra pendientes con los 5 mejores precios en el momento de la ejecucion

# %%
plot_dist('sell', 'lensell10')
